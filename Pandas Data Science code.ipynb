# %%
#Impoerting Libraries
import pandas as pd
import numpy as np

# %%
#Create Series
s=pd.Series([32,43,35,6,np.nan, 8,26])
s
# Out:
# 0    32.0
# 1    43.0
# 2    35.0
# 3     6.0
# 4     NaN
# 5     8.0
# 6    26.0
# dtype: float64

# %%
#Sort the Series
s.sort_values(ascending=False)
# Out:
# 1    43.0
# 2    35.0
# 0    32.0
# 6    26.0
# 5     8.0
# 3     6.0
# 4     NaN
# dtype: float64

# %%
#Create Dataframe by taking date as index and random records
df=pd.date_range(start="2016",end="2021",freq='A')
df
# Out:
# DatetimeIndex(['2016-12-31', '2017-12-31', '2018-12-31', '2019-12-31',
#                '2020-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
df1=pd.DataFrame(np.random.randn(5,5),index=df,columns=['A','B','C','D','E'])
df1
# Out:
#                    A         B         C         D         E
# 2016-12-31 -0.091492  0.673511  1.015099  0.609231  0.247184
# 2017-12-31  0.611347  0.647477 -0.571474 -0.388073 -0.609766
# 2018-12-31  1.028908 -1.191728 -0.445669 -0.175496  0.728437
# 2019-12-31 -0.304371  1.483294 -0.179028  0.135269 -0.776595
# 2020-12-31  0.440000 -0.250130  0.263451 -0.458052 -2.261423

# %%
# Create Dataframe from Dictionaries And Manipulate it
df2=pd.DataFrame({'A':[1,2,3,4,5],
                  'B':pd.date_range(start='2016',end='2021',freq='Y'),
                  'C':pd.Series(1,index=list([1,2,3,4,5]),dtype='int32'),
                  'D':pd.Categorical(['TRUE','FALSE','TRUE','FALSE','TRUE']),
                   'E':'Shiva'})

df2
# Out:
#    A          B  C      D      E
# 1  1 2016-12-31  1   TRUE  Shiva
# 2  2 2017-12-31  1  FALSE  Shiva
# 3  3 2018-12-31  1   TRUE  Shiva
# 4  4 2019-12-31  1  FALSE  Shiva
# 5  5 2020-12-31  1   TRUE  Shiva

# %%
df2['F']=np.array([4,5,6,7,8])
df2
# Out:
#    A          B  C      D      E  F
# 1  1 2016-12-31  1   TRUE  Shiva  4
# 2  2 2017-12-31  1  FALSE  Shiva  5
# 3  3 2018-12-31  1   TRUE  Shiva  6
# 4  4 2019-12-31  1  FALSE  Shiva  7
# 5  5 2020-12-31  1   TRUE  Shiva  8

# %%
#Insert New Column into dataframe
df2.insert(5,'G',['SS','MM','KK','RR','AA'],True)
df2
# Out:
#    A          B  C      D      E   G  F
# 1  1 2016-12-31  1   TRUE  Shiva  SS  4
# 2  2 2017-12-31  1  FALSE  Shiva  MM  5
# 3  3 2018-12-31  1   TRUE  Shiva  KK  6
# 4  4 2019-12-31  1  FALSE  Shiva  RR  7
# 5  5 2020-12-31  1   TRUE  Shiva  AA  8

# %%
#Drop column from dataframe
df2.drop('G',inplace=True,axis=1)
df2
# Out:
#    A          B  C      D      E  F
# 1  1 2016-12-31  1   TRUE  Shiva  4
# 2  2 2017-12-31  1  FALSE  Shiva  5
# 3  3 2018-12-31  1   TRUE  Shiva  6
# 4  4 2019-12-31  1  FALSE  Shiva  7
# 5  5 2020-12-31  1   TRUE  Shiva  8

# %%
df2.insert(5,'G',['SS','SS','KK','RR','AA'],True)
df2
# Out:
#    A          B  C      D      E   G  F
# 1  1 2016-12-31  1   TRUE  Shiva  SS  4
# 2  2 2017-12-31  1  FALSE  Shiva  SS  5
# 3  3 2018-12-31  1   TRUE  Shiva  KK  6
# 4  4 2019-12-31  1  FALSE  Shiva  RR  7
# 5  5 2020-12-31  1   TRUE  Shiva  AA  8

# %%
df2
# Out:
#    A          B  C      D      E   G  F
# 1  1 2016-12-31  1   TRUE  Shiva  SS  4
# 2  2 2017-12-31  1  FALSE  Shiva  SS  5
# 3  3 2018-12-31  1   TRUE  Shiva  KK  6
# 4  4 2019-12-31  1  FALSE  Shiva  RR  7
# 5  5 2020-12-31  1   TRUE  Shiva  AA  8

# %%
#Count values of particular Column
df2['G'].value_counts()
# Out:
# SS    2
# RR    1
# KK    1
# AA    1
# Name: G, dtype: int64

# %%
df2['F'].sum()
# Out:
# 30

# %%
df2.info(); df2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 1 to 5
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int64
#  1   B       5 non-null      datetime64[ns]
#  2   C       5 non-null      int32
#  3   D       5 non-null      category
#  4   E       5 non-null      object
#  5   G       5 non-null      object
#  6   F       5 non-null      int32
# dtypes: category(1), datetime64[ns](1), int32(2), int64(1), object(2)
# memory usage: 541.0+ bytes
#               A    C         F
# count  5.000000  5.0  5.000000
# mean   3.000000  1.0  6.000000
# std    1.581139  0.0  1.581139
# min    1.000000  1.0  4.000000
# 25%    2.000000  1.0  5.000000
# 50%    3.000000  1.0  6.000000
# 75%    4.000000  1.0  7.000000
# max    5.000000  1.0  8.000000

# %%
df2.sort_index(axis=1,ascending=True)
# Out:
#    A          B  C      D      E  F   G
# 1  1 2016-12-31  1   TRUE  Shiva  4  SS
# 2  2 2017-12-31  1  FALSE  Shiva  5  SS
# 3  3 2018-12-31  1   TRUE  Shiva  6  KK
# 4  4 2019-12-31  1  FALSE  Shiva  7  RR
# 5  5 2020-12-31  1   TRUE  Shiva  8  AA

# %%
# Sort Values by G
df2.sort_values(by='G')
# Out:
#    A          B  C      D      E   G  F
# 5  5 2020-12-31  1   TRUE  Shiva  AA  8
# 3  3 2018-12-31  1   TRUE  Shiva  KK  6
# 4  4 2019-12-31  1  FALSE  Shiva  RR  7
# 1  1 2016-12-31  1   TRUE  Shiva  SS  4
# 2  2 2017-12-31  1  FALSE  Shiva  SS  5

# %%
df2[0:2]
# Out:
#    A          B  C      D      E   G  F
# 1  1 2016-12-31  1   TRUE  Shiva  SS  4
# 2  2 2017-12-31  1  FALSE  Shiva  SS  5

# %%
# Take and print particular column and all rows
y=df2.loc[:,['E']]
y
# Out:
#        E
# 1  Shiva
# 2  Shiva
# 3  Shiva
# 4  Shiva
# 5  Shiva

# %%
df2.sort_index()
# Out:
#    A          B  C      D      E   G  F
# 1  1 2016-12-31  1   TRUE  Shiva  SS  4
# 2  2 2017-12-31  1  FALSE  Shiva  SS  5
# 3  3 2018-12-31  1   TRUE  Shiva  KK  6
# 4  4 2019-12-31  1  FALSE  Shiva  RR  7
# 5  5 2020-12-31  1   TRUE  Shiva  AA  8

# %%
df2['F'].max()
# Out:
# 8

# %%
# Acessing particular item from dataframe
df2.loc[5:,['G']]
# Out:
#     G
# 5  AA

# %%
df2.iloc[1:3,1:5]
# Out:
#            B  C      D      E
# 2 2017-12-31  1  FALSE  Shiva
# 3 2018-12-31  1   TRUE  Shiva

# %%
df2.loc[1:3,:]
# Out:
#    A          B  C      D      E   G  F
# 1  1 2016-12-31  1   TRUE  Shiva  SS  4
# 2  2 2017-12-31  1  FALSE  Shiva  SS  5
# 3  3 2018-12-31  1   TRUE  Shiva  KK  6

# %%
df2[df2['F']>5]
# Out:
#    A          B  C      D      E   G  F
# 3  3 2018-12-31  1   TRUE  Shiva  KK  6
# 4  4 2019-12-31  1  FALSE  Shiva  RR  7
# 5  5 2020-12-31  1   TRUE  Shiva  AA  8

# %%
df2
# Out:
#    A          B  C      D      E   G  F    H    H    H    H
# 1  1 2016-12-31  1   TRUE  Shiva  SS  4    s    s    s    s
# 2  2 2017-12-31  1  FALSE  Shiva  SS  5    A    A    A    A
# 3  3 2018-12-31  1   TRUE  Shiva  KK  6    B    B    B    B
# 4  4 2019-12-31  1  FALSE  Shiva  RR  7  NaN  NaN  NaN  NaN
# 5  5 2020-12-31  1   TRUE  Shiva  AA  8  NaN  NaN  NaN  NaN

# %%
#Handling Null Values
df2.insert(7,'H',['s','A','B',np.nan,np.nan],True)
df2.drop('H',inplace=True,axis=1)

# %%
df2.insert(7,'H',['s','A','B',np.nan,np.nan],True)

# %%
df2
# Out:
#    A          B  C      D      E   G  F    H
# 1  1 2016-12-31  1   TRUE  Shiva  SS  4    s
# 2  2 2017-12-31  1  FALSE  Shiva  SS  5    A
# 3  3 2018-12-31  1   TRUE  Shiva  KK  6    B
# 4  4 2019-12-31  1  FALSE  Shiva  RR  7  NaN
# 5  5 2020-12-31  1   TRUE  Shiva  AA  8  NaN

# %%
df2['H'].isnull().sum()
# Out:
# 2

# %%
df2['H'].fillna(value='C')
# Out:
# 1    s
# 2    A
# 3    B
# 4    C
# 5    C
# Name: H, dtype: object

# %%
d=pd.DataFrame({'A':np.arange(4),
               'B':[2,8,9,5]})
d
# Out:
#    A  B
# 0  0  2
# 1  1  8
# 2  2  9
# 3  3  5

# %%
s=d.apply(lambda a:a.max()-a.min())
s
# Out:
# A    3
# B    7
# dtype: int64

# %%
#Left and Right Join
left=pd.DataFrame({'A':[2,4,5,6],'B':[6,7,2,1]})
left
# Out:
#    A  B
# 0  2  6
# 1  4  7
# 2  5  2
# 3  6  1

# %%
right=pd.DataFrame({'A':[1,7,2,6],'B':[7,7,0,1]})
right
# Out:
#    A  B
# 0  1  7
# 1  7  7
# 2  2  0
# 3  6  1

# %%
pd.merge(left,right, on='A')
# Out:
#    A  B_x  B_y
# 0  2    6    0
# 1  6    1    1

# %%
pd.merge(right,left, on='A')
# Out:
#    A  B_x  B_y
# 0  2    0    6
# 1  6    1    1

# %%
#Time series
d=pd.date_range(start='20180301',end='20210301',freq='MS')
d
# Out:
# DatetimeIndex(['2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01',
#                '2018-07-01', '2018-08-01', '2018-09-01', '2018-10-01',
#                '2018-11-01', '2018-12-01', '2019-01-01', '2019-02-01',
#                '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01',
#                '2019-07-01', '2019-08-01', '2019-09-01', '2019-10-01',
#                '2019-11-01', '2019-12-01', '2020-01-01', '2020-02-01',
#                '2020-03-01', '2020-04-01', '2020-05-01', '2020-06-01',
#                '2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01',
#                '2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01',
#                '2021-03-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
c=pd.DataFrame({'Id':[1,2,3,4,5],
                'Marks':[85,65,42,23,36],
               'grade':['A','B','C','D','E']})
c
# Out:
#    Id  Marks grade
# 0   1     85     A
# 1   2     65     B
# 2   3     42     C
# 3   4     23     D
# 4   5     36     E

# %%
c['Grade']=c['grade'].astype('category')

# %%
c.drop('grade',inplace=True,axis=1)

# %%
c['Grade'].astype('category')
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# Name: Grade, dtype: category
# Categories (5, object): ['A', 'B', 'C', 'D', 'E']

# %%
c['Grade']=c['Grade'].cat.set_categories(['Excellent','very good','good','bad','Fail'])

# %%
import matplotlib.pyplot as plt
t=pd.Series(np.random.randn(100),index=pd.date_range('01/02/2016',periods=100))
t=t.cumsum()
t.plot()
# Out:
# <AxesSubplot:>
